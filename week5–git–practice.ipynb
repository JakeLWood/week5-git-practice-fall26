# %% [markdown]
# # Week 5 Practice Notebook

# %% [markdown]
# ### You will use this sample notebook to practice with GitHub!

# %%
#Generate a simple function that describes and calls a list of five items at a grocery store and prints the list in order.
def grocery_list():
    items = ["milk", "bread", "eggs", "cheese", "apples"]
    print("Grocery List:")
    for item in items:
        print(item)

grocery_list()
